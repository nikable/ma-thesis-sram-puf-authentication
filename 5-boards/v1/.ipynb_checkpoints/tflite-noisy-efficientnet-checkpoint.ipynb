# %%
# !python --version
# Out:
# Python 3.9.16

# %%
import numpy as np
np.version.version
# Out:
# '1.23.5'

# %%
import tensorflow as tf
assert tf.__version__.startswith('2')

# %%
from tflite_model_maker import model_spec
from tflite_model_maker import image_classifier
from tflite_model_maker.config import ExportFormat
from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.image_classifier import DataLoader

import matplotlib.pyplot as plt

# %%
# !pip3 install chardet

# %%
# image_path = os.path.join(os.path.dirname("/content/drive/MyDrive/tflite/boards/boards50"))
## 3 classes with RGB converted images.. bottom-20 corrupted dataset
#data = DataLoader.from_folder("/home/stark/thesis/sram/dataxmc/tflite/corrupted-20230610T144029Z-001/corrupted/20-bottom-rgb")

## 3 classes with RGB converted... top-20 corrupted dataset
data = DataLoader.from_folder("/home/stark/thesis/sram/dataxmc/tflite/corrupted-dataset/20-top-rgb")
# Out:
# INFO:tensorflow:Load image with size: 303, num_label: 3, labels: board0009, board0040, board0098.

# %%
train_data, rest_data = data.split(0.8)
validation_data, test_data = rest_data.split(0.5)

# %%
## show dataset with class labels
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(data.gen_dataset().unbatch().take(25)):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)
  plt.xlabel(data.index_to_label[label.numpy()])
plt.show()

# %%
## EfficientNet-Lite0 evaluating v1
#model = image_classifier.create(train_data, 
#                                model_spec=model_spec.get('efficientnet_lite0'), 
#                                validation_data=validation_data,
#                                learning_rate=0.005,
#                                batch_size=32,
#                                dropout_rate=0.60,
#                                epochs=5)


## EfficientNet-Lite0 evaluating v1
model = image_classifier.create(train_data, 
                                model_spec=model_spec.get('mobilenet_v2'), 
                                validation_data=validation_data,
                                learning_rate=0.0005,
                                batch_size=32,
                                dropout_rate=0.60,
                                epochs=6)



#model = image_classifier.create(train_data)



#model = image_classifier.create(train_data)
# Out:
# INFO:tensorflow:Retraining the models...
# INFO:tensorflow:Retraining the models...
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_4 (Hub  (None, 1280)             2257984
#  KerasLayerV1V2)
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 3)                 3843
#
# ...
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None
# Epoch 1/6
# 7/7 [==============================] - 9s 901ms/step - loss: 1.6064 - accuracy: 0.3482 - val_loss: 1.0449 - val_accuracy: 0.1667
# Epoch 2/6
# 7/7 [==============================] - 7s 915ms/step - loss: 1.4962 - accuracy: 0.4062 - val_loss: 0.9503 - val_accuracy: 0.4333
# Epoch 3/6
# ...

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_4 (Hub  (None, 1280)             2257984
#  KerasLayerV1V2)
#
#  dropout_4 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 3)                 3843
#
# ...
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.5975 - accuracy: 0.9355

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
epochs_range = range(6)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.export(export_dir='/home/stark/thesis/sram/dataxmc/tflite/experiments/corrupted/top-20')
# Out:
# 2023-06-16 22:29:21.208969: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /tmp/tmp724ks_56/assets
# INFO:tensorflow:Assets written to: /tmp/tmp724ks_56/assets
# 2023-06-16 22:29:26.387155: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-06-16 22:29:26.387255: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-06-16 22:29:26.474794: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1164] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 1639 nodes (1367), 2439 edges (2165), time = 37.032ms.
#   function_optimizer: function_optimizer did nothing. time = 0.014ms.
#
# ...

# %%
model.export(export_dir='/home/stark/thesis/sram/dataxmc/tflite/experiments/corrupted/top-20/', export_format=ExportFormat.LABEL)
# Out:
# INFO:tensorflow:Saving labels in /home/stark/thesis/sram/dataxmc/tflite/experiments/corrupted/top-20/labels.txt
# INFO:tensorflow:Saving labels in /home/stark/thesis/sram/dataxmc/tflite/experiments/corrupted/top-20/labels.txt

# %%
model.evaluate_tflite('/home/stark/thesis/sram/dataxmc/tflite/experiments/corrupted/top-20/model.tflite', test_data)
# Out:
# {'accuracy': 0.9354838709677419}
