# %%
# !python --version
# Out:
# Python 3.9.16

# %%
import numpy as np
np.version.version
# Out:
# '1.23.5'

# %%
import tensorflow as tf
assert tf.__version__.startswith('2')
# Out:
# 2023-07-15 14:39:35.760519: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-15 14:39:35.760532: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
from tflite_model_maker import model_spec
from tflite_model_maker import image_classifier
from tflite_model_maker.config import ExportFormat
from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.image_classifier import DataLoader

import matplotlib.pyplot as plt
# Out:
# /home/stark/miniconda3/envs/py39/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/stark/miniconda3/envs/py39/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.4 and is not supported.
# Some things might work, some things might not.
# ...

# %%
# !pip3 install chardet

# %%
## 3 classes with RGB converted... intact dataset
data = DataLoader.from_folder("/home/stark/thesis/sram/dataxmc/tflite/dataset/intact/intact-data-colab")
# Out:
# INFO:tensorflow:Load image with size: 303, num_label: 3, labels: board000B, board002A, board003D.
# 2023-07-15 14:39:49.985669: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/stark/miniconda3/envs/py39/lib/python3.9/site-packages/cv2/../../lib64:
# 2023-07-15 14:39:49.986540: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-07-15 14:39:49.986564: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (stark-labs): /proc/driver/nvidia/version does not exist
# ...

# %%
#train_data, rest_data = data.split(0.8)
#validation_data, test_data = rest_data.split(0.5)

train_data, test_data = data.split(0.8)

# %%
## show dataset with class labels
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(data.gen_dataset().unbatch().take(25)):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)
  plt.xlabel(data.index_to_label[label.numpy()])
plt.show()

# %%
## EfficientNet-Lite0 with default parameters
#model = image_classifier.create(train_data, validation_data=validation_data)

## EfficientNet-Lite0 with customized hyperparameters
model = image_classifier.create(train_data, 
                                model_spec=model_spec.get('efficientnet_lite0'), 
                                validation_data=test_data,
                                learning_rate=0.0005,
                                batch_size=32,
                                dropout_rate=0.75,
                                epochs=5)
# Out:
# INFO:tensorflow:Retraining the models...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2 (HubKe  (None, 1280)             3413024
#  rasLayerV1V2)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# ...
# Total params: 3,416,867
# Trainable params: 3,843
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# 7/7 [==============================] - 9s 1s/step - loss: 1.0223 - accuracy: 0.5848 - val_loss: 0.3470 - val_accuracy: 0.9672
# Epoch 2/5
# 7/7 [==============================] - 7s 978ms/step - loss: 0.4674 - accuracy: 0.9420 - val_loss: 0.4626 - val_accuracy: 0.9672
# Epoch 3/5
# 7/7 [==============================] - 7s 978ms/step - loss: 0.5095 - accuracy: 0.9777 - val_loss: 0.4823 - val_accuracy: 0.9672
# ...

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_5 (Hub  (None, 1280)             3413024
#  KerasLayerV1V2)
#
#  dropout_5 (Dropout)         (None, 1280)              0
#
#  dense_5 (Dense)             (None, 3)                 3843
#
# ...
# Total params: 3,416,867
# Trainable params: 3,843
# Non-trainable params: 3,413,024
# _________________________________________________________________

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6948 - accuracy: 1.0000

# %%
acc = model.history.history['accuracy']
val_acc = model.history.history['val_accuracy']
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
epochs_range = range(7)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.export(export_dir='/home/stark/thesis/sram/dataxmc/tflite/experiments/intact/v_local')
# Out:
# 2023-07-12 19:18:47.036760: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /tmp/tmpgk5ltjyt/assets
# INFO:tensorflow:Assets written to: /tmp/tmpgk5ltjyt/assets
# 2023-07-12 19:18:51.969724: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2023-07-12 19:18:51.969830: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-07-12 19:18:52.016780: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1164] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 913 nodes (656), 923 edges (664), time = 27.824ms.
#   function_optimizer: function_optimizer did nothing. time = 0.014ms.
#
# ...

# %%
model.export(export_dir='/home/stark/thesis/sram/dataxmc/tflite/experiments/intact/v_local', export_format=ExportFormat.LABEL)
# Out:
# INFO:tensorflow:Saving labels in /home/stark/thesis/sram/dataxmc/tflite/experiments/intact/v_local/labels.txt
# INFO:tensorflow:Saving labels in /home/stark/thesis/sram/dataxmc/tflite/experiments/intact/v_local/labels.txt

# %%
model.evaluate_tflite('/home/stark/thesis/sram/dataxmc/tflite/experiments/intact/v_local/model.tflite', test_data)
# Out:
# {'accuracy': 0.967741935483871}
